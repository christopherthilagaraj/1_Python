# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
input("Enter your institite name? :")
# Out:
# Enter your institite name? : HOPE AI
# 'HOPE AI'

# %%
input("Enter Your name:")
input("Enter Your age:")
input("Enter Your School name:")
input("Enter drgree:")
# Out:
# Enter Your name: Raj
# Enter Your age: 15
# Enter Your School name: Guru School
# Enter drgree: B.E CSE
# 'B.E CSE'

# %%
#Addition
a=int(input("Enter A Value:-"))
b=int(input("Enter B Value:-"))
result=a+b
print("add=",result)
# Out:
# Enter A Value:- 3
# Enter B Value:- 4
# add= 7

# %%
#Subtraction
a=int(input("Enter A Value:-"))
b=int(input("Enter B Value:-"))
result=a-b
print("Sub=",result)
# Out:
# Enter A Value:- 33
# Enter B Value:- 4
# Sub= 29

# %%
#Mult
a=int(input("Enter A Value:-"))
b=int(input("Enter B Value:-"))
result=a*b
print("Mul=",result)
# Out:
# Enter A Value:- 44
# Enter B Value:- 5
# Mul= 220

# %%
#Div
a=int(input("Enter A Value:-"))
b=int(input("Enter B Value:-"))
result=a/b
print("Float Div=",result)
# Out:
# Enter A Value:- 76
# Enter B Value:- 31
# Float Div= 2.4516129032258065

# %%
#Floor Div
a=int(input("Enter A Value:-"))
b=int(input("Enter B Value:-"))
result=round(a/b)
print("Floor Div=",result)
# Out:
# Enter A Value:- 76
# Enter B Value:- 31
# Floor Div= 2

# %%
#Modulo
a=int(input("Enter A Value:-"))
b=int(input("Enter B Value:-"))
result=a%b
print("Modulo=",result)
# Out:
# Enter A Value:- 76
# Enter B Value:- 31
# Modulo= 14

# %%
#Power
a=int(input("Enter A Value:-"))
b=int(input("Enter B Value:-"))
result=a**b
print("Power=",result)
# Out:
# Enter A Value:- 4
# Enter B Value:- 4
# Power= 256
