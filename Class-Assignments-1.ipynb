# %%
from Multiple_Functions import multipleFunctions

# %%
multipleFunctions.oddEvent()
# Out:
# Enter the number: 56
# Even Number
# 'Even Number'

# %%
multipleFunctions.BMI()
# Out:
# Enter your Weight:- 55
# Very sererely obsese
# 'Very sererely obsese'

# %%
multipleFunctions.AI_SubFields()
# Out:
# Sub-Fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multipleFunctions.MarriageElegible("Male",40)
# Out:
# Gender= Male, Age= 40 Your are Eligible to marriage

# %%
multipleFunctions.CalculateMark1()
# Out:
# Subject1= 45
# Subject2= 55
# Subject3= 77
# Subject4= 44
# Subject5= 88
# Total:  309
# 61.8
